# %% [markdown]
# ### Description: This is a sentimental analysis program that parses the tweets fetched from twitter using python

# %%
#import the libraries
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
#Load the api_keys
keys = pd.read_csv("keys.csv") #import your own keys and assign them below, make sure that they are not publicly visible.

# %%
#Assign keys
consumerKey = keys.iloc[0, 0]
consumerSecret = keys.iloc[0, 1]
accessToken = keys.iloc[0, 2]
accessTokenSecret = keys.iloc[0, 3]

# %%
#Create the authentication object
authenticate = tweepy.OAuthHandler(consumerKey, consumerSecret)

#access token and access token secret
authenticate.set_access_token(accessToken, accessTokenSecret)

#create the api object while passing in the auth information
api = tweepy.API(authenticate, wait_on_rate_limit = True)

# %%
#Extract 100 tweets from a twitter user
posts = api.user_timeline(screen_name = "BillGates", count = 100, lang = "en", tweet_mode = "extended")

#Print the last 5 tweets from the account
print("Show the 5 recent tweets: \n")

i = 1
for tweet in posts[0:5]:
    print(str(i) + ")" + tweet.full_text + "\n")
    i = i + 1
# Out:
# Show the 5 recent tweets:
#
# 1)RT @GlobalFund: Speaking from villages, riverbanks and rural clinics, frontline health workers and malaria volunteers share stories of what…
#
# 2)Virologist Ruth Bishop pioneered the research that led to the discovery of rotavirus. Her legacy continues both as a role model for other researchers and in the millions of children’s lives that have been saved because of her heroic work: https://t.co/qjroJpzqTc #IWD2021 https://t.co/rEtrmXwFxJ
#
# 3)RT @AnitaZaidi: On International Women’s Day, join me in celebrating some of the inspiring women who made #COVID19 vaccines possible. Know…
#
# 4)Thank you @BarackObama for the kind words. Your leadership at the 2015 Paris climate conference helped prove that global cooperation on climate is possible and gives me hope that we can reach our goal of zero emissions. https://t.co/990iHWgQqx
#
# 5)@EDFaction @Breakthrough Thank you for your partnership, @EDFAction, and for sharing what all of us can do to avoid a climate disaster.

# %%
#Create a dataframe with a column called Tweets
df = pd.DataFrame([tweet.full_text for tweet in posts], columns = ["Tweets"])
df.head()
# Out:
#                                               Tweets
# 0  RT @GlobalFund: Speaking from villages, riverb...
# 1  Virologist Ruth Bishop pioneered the research ...
# 2  RT @AnitaZaidi: On International Women’s Day, ...
# 3  Thank you @BarackObama for the kind words. You...
# 4  @EDFaction @Breakthrough Thank you for your pa...

# %%
#clean the text

#Create a function to clean the tweets
def cleantxt(text):
    text = re.sub(r"@[A-Za-z0-9]+", "", text) #Removes @ mentions
    text = re.sub(r"#", "", text) #Removing the # symbol
    text = re.sub(r"RT[\s]+", "", text) #Removing RT
    text = re.sub(r"https?:\/\/\S+", "", text) #Removing hyperlinks
    return text

df["Tweets"] = df["Tweets"].apply(cleantxt)
    
#Show the cleaned text
df
# Out:
#                                                Tweets
# 0   : Speaking from villages, riverbanks and rural...
# 1   Virologist Ruth Bishop pioneered the research ...
# 2   : On International Women’s Day, join me in cel...
# 3   Thank you  for the kind words. Your leadership...
# 4     Thank you for your partnership, , and for sh...
# ..                                                ...
# 95  Each week, we’ll talk about some of the bigges...
# 96  I’m teaming up with Rashida Jones to ask the b...
# 97  I look forward to working with the new adminis...
# 98  Congratulations to President-Elect Biden and V...
# 99  Here in Washington, we always vote by mail. It...
#
# [100 rows x 1 columns]

# %%
#Create a fuction to get the subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#Create a fuction to get the subjectivity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

#Creating columns for subjectivity and polarity
df["Subjectivity"] = df["Tweets"].apply(getSubjectivity)
df["Polarity"] = df["Tweets"].apply(getPolarity)

#Show new columns 
df
# Out:
#                                                Tweets  Subjectivity  Polarity
# 0   : Speaking from villages, riverbanks and rural...      0.000000  0.000000
# 1   Virologist Ruth Bishop pioneered the research ...      0.637500  0.287500
# 2   : On International Women’s Day, join me in cel...      0.666667  0.166667
# 3   Thank you  for the kind words. Your leadership...      0.633333  0.200000
# 4     Thank you for your partnership, , and for sh...      0.000000  0.000000
# ..                                                ...           ...       ...
# 95  Each week, we’ll talk about some of the bigges...      0.571429  0.357143
# 96  I’m teaming up with Rashida Jones to ask the b...      0.199351  0.016234
# 97  I look forward to working with the new adminis...      0.577273  0.268182
# 98  Congratulations to President-Elect Biden and V...      0.750000  0.250000
# 99  Here in Washington, we always vote by mail. It...      0.431250  0.350000
#
# [100 rows x 3 columns]

# %%
#Plot the wordcloud
allwords = "".join([twts for twts in df["Tweets"]])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis("off")
plt.show()

# %%
#Create a function to compute the negative, neutral and positive analysis
def getAnalysis(score):
    if score < 0:
        return "Negative"
    if score > 0:
        return "Positive"
    if score == 0:
        return "Neutral"

#Making column for analysis
df["Analysis"] = df["Polarity"].apply(getAnalysis)

#printing df with new analysis column
df
# Out:
#                                                Tweets  Subjectivity  Polarity  \
# 0   : Speaking from villages, riverbanks and rural...      0.000000  0.000000
# 1   Virologist Ruth Bishop pioneered the research ...      0.637500  0.287500
# 2   : On International Women’s Day, join me in cel...      0.666667  0.166667
# 3   Thank you  for the kind words. Your leadership...      0.633333  0.200000
# 4     Thank you for your partnership, , and for sh...      0.000000  0.000000
# ..                                                ...           ...       ...
# 95  Each week, we’ll talk about some of the bigges...      0.571429  0.357143
# 96  I’m teaming up with Rashida Jones to ask the b...      0.199351  0.016234
# 97  I look forward to working with the new adminis...      0.577273  0.268182
# 98  Congratulations to President-Elect Biden and V...      0.750000  0.250000
# 99  Here in Washington, we always vote by mail. It...      0.431250  0.350000
#
#     Analysis
# 0    Neutral
# 1   Positive
# 2   Positive
# 3   Positive
# 4    Neutral
# ..       ...
# 95  Positive
# 96  Positive
# 97  Positive
# 98  Positive
# 99  Positive
#
# [100 rows x 4 columns]

# %%
#Printing all the positive tweets
j = 1
sortedDF = df.sort_values(by = ["Polarity"])
for i in range(0, sortedDF.shape[0]):
    if sortedDF["Analysis"][i] == "Positive":
        print(str(j) + ")" + sortedDF["Tweets"][i])
        print()
        j = j + 1
# Out:
# 1)Virologist Ruth Bishop pioneered the research that led to the discovery of rotavirus. Her legacy continues both as a role model for other researchers and in the millions of children’s lives that have been saved because of her heroic work:  IWD2021
#
# 2): On International Women’s Day, join me in celebrating some of the inspiring women who made COVID19 vaccines possible. Know…
#
# 3)Thank you  for the kind words. Your leadership at the 2015 Paris climate conference helped prove that global cooperation on climate is possible and gives me hope that we can reach our goal of zero emissions.
#
# 4)Moving to a green economy is the biggest challenge the world has ever faced. I’m optimistic we can do it, but need to make sure it benefits everyone—including those workers and communities who depend on the fossil fuels that we need to get rid of.
#
# 5)We can’t avoid a climate disaster without corporate leaders making courageous decisions now. I hope to work with  on building the markets for the clean technologies the world needs. Thank you for the kind words, Herbert.
#
# 6)Delivering vaccines to those who need them most, no matter where they live or how much money they have, is the only way to end the pandemic and begin the recovery. This is an important milestone.
#
# 7)_H2020    To get to net zero, we need innovation to replace fossil fuels in everyday products like plastics.  is one of the many companies leading on this important work.
#
# 8)We're fortunate to have an Energy Secretary who's focused on creating high-quality jobs to build a clean energy economy. I look forward to working with  on clean tech innovation and deployment.
#
# 9)Thanks  and  for a great conversation about how we can avoid a climate disaster.
#
# 10)I’m looking forward to joining  to talk about climate change, our foundation’s work in response to the pandemic, and more.
#
# 11)It’s encouraging to have  John Kerry representing the U.S. to the world. Now that we've rejoined the Paris Climate Agreement, it's going to take ambitious action from U.S. leaders and those around the globe to avoid a climate disaster.
#
# 12)Thanks  and  for having me on the show to talk about climate change and COVID-19 – two urgent global issues that need global collaboration.
#
# 13)  I always have fun talking to . Thanks for inviting me to talk about climate change and my new book.
#
# 14): I’m grateful for new commitments from the EU, Germany, Canada, Japan, and the U.S. to help make safe and effective COVID-…
#
# 15)I’m inspired by ’s activism and humanitarian work. Thanks to  and  for hosting our discussion about climate change and how everyone can help.
#
# 16) Thanks  for talking with me about this challenge and why we need to act now.
#
# 17)Meaningful action from business leaders will require the courage to take risks that many companies aren't used to taking.
#
# 18)Thanks to , , and everyone who joined our virtual conversation about climate change. Great to have so much support from my hometown for this important work.
#
# 19)Great to see this important step as the United States resumes our global leadership on climate change. Looking forward to working with  and Congress on a plan to ensure we reach net zero by 2050.
#
# 20)Thanks to  for hosting the launch of my virtual book tour. It was great to hear so many thoughtful questions about what we can all do to help avoid a climate disaster.
#
# 21): Bill Gates on Climate Change, Covid and Whether He Has Too Much Influence
#
# 22)Thanks for inviting me on the podcast, .
#
# 23)Thank you, _RDG. We have a lot of work ahead of us to reach net-zero emissions by 2050 and avoid a climate disaster. Your leadership of COP26 is critical. Thanks also to ,  and  for hosting the London stop of my virtual book tour!
#
# 24)It was great to talk with  about my new book and the solutions we need to fight climate change.
#
# 25)  Thank you  for inviting me to talk about climate change. Solving it won’t be easy, but I believe we can do it.
#
# 26)Thanks for another great conversation !
#
# 27) Thanks for inviting me to be a guest editor. We need every business leader and every industry to play a role in the fight against climate change.
#
# 28)I had a great time working with  on this special digital issue about climate change. The entire business community has a role to play—and we need to start now.
#
# 29)How to Avoid a Climate Disaster is available now. I hope you’ll check out the book, but more importantly, I hope you’ll do what you can to help keep the planet livable for generations to come:
#
# 30): In a digital cover story, we talked to  about his new book, "How to Avoid a Climate Disaster."
#
# 31)To avoid a climate disaster, we need to eliminate emissions from the ways we create electricity, grow food, make things, move around, and heat and cool our buildings. It won’t be easy, but I believe we can do it. This book is about what it will take.
#
# 32)I enjoyed spending time with  recently in Seattle. We talked about why I’m optimistic that the world can get to zero greenhouse gas emissions and avoid a climate disaster:
#
# 33)I’m thrilled to join , _RDG, , , , , ,  and Monica Padman, Sal Khan, and Ariel Bissett to discuss how the world can work to avoid a climate disaster:
#
# 34)When it comes to preventing pandemics, scientific tools alone aren’t enough. We also need new capabilities, including a global alert system and infectious disease first responders (or what I like to call a pandemic fire squad):
#
# 35)This has been a year unlike any other in our lifetimes. In our new Annual Letter, Melinda and I talk about how we can turn the hard-won lessons of the pandemic into a healthier, more equal future for all.
#
# 36): I believe that women can be the architects of a better world.
#
# Their stories have instilled in me both a sense of urgenc…
#
# 37)One of the benefits of being 65 is that I’m eligible for the COVID-19 vaccine. I got my first dose this week, and I feel great. Thank you to all of the scientists, trial participants, regulators, and frontline healthcare workers who got us to this point.
#
# 38)It’s great to see President Biden elevate science leadership to a cabinet-level position. Congratulations _lander.
#
# 39)And while COVID-19 will rightfully continue to dominate the agenda, the United States also has the opportunity to lead the world in avoiding a climate disaster. The President is taking a great first step by rejoining the Paris Climate Accord.
#
# 40)With Americans across the country working together, more people get a COVID-19 vaccine every day, bringing us closer to a time when life will look much more like normal. Until then, we can slow the spread of the virus and save lives by continuing to distance and wear masks.
#
# 41)MLKDay has long been a national day of service. As we celebrate the first without Congressman John Lewis, I'm thinking about his powerful call to remain hopeful about the future as we work to make our country—and our world—a better place.
#
# 42)It’s great to see India’s leadership in scientific innovation and vaccine manufacturing capability as the world works to end the COVID-19 pandemic
#
# 43): The best emergency system is a strong primary health system—powered by community and frontline health workers. Now is t…
#
# 44)What does Rashida Jones have on her shopping list? That’s just one of the many questions that didn’t make it into our podcast. You can listen to some of the big questions we did tackle here:
#
# 45)2021 will be better than 2020. Here’s why:
#
# 46)Standing up for science has never been more important. Congratulations to Dr. Anthony Fauci and Dr. Salim Abdool Karim on receiving this honor.
#
# 47)I've known and learned from  for more than 40 years. I'm glad to see  team up with  to mentor and support companies working to create more economic empowerment opportunities for people across the world.
#
# 48)This book has nothing to do with viruses or pandemics. But it is surprisingly relevant for these times.  provides a brilliant and gripping account of another era of widespread anxiety: the years 1940 and 1941.
#
# 49)Monoclonal antibodies are one of the most promising treatments we have for COVID-19, thanks in large part to R&amp;D by Canadian scientists. Because of their generosity, people all around the world will have access to this potentially lifesaving treatment.
#
# 50): We’re looking for new ways to advance AlzheimersResearch. If you have an idea for tools, models, or algorithms that will expa…
#
# 51)Like many people, I’ve tried to deepen my understanding of systemic racism in recent months. If you’re interested in learning more about the lives caught up in our country's justice system, I highly recommend  by Michelle Alexander.
#
# 52)The season finale of our podcast features two incredible people who are using their positions as artists to change the world for the better.
#
# 53)Thanks for the great conversation, Carlos.
#
# 54)Bill Foege and Viktor Zdanov are phenomenal examples of what it means to harness science for global health. A well-deserved honor.
#
# 55)Here are five books that I’d recommend as we wrap up 2020. I hope you find something that helps you—or the book lover in your life—finish the year on a good note.
#
# 56)Are we actually making progress on climate change? Can we really prevent a climate disaster? In this week’s podcast, Rashida and I take on perhaps our biggest question yet with Pulitzer Prize-winning author .
#
# 57)This new quiz from  is a clever way to fight misconceptions and “upgrade your worldview” about the incredible progress the world has made toward the Sustainable Development Goals to end poverty, fight inequality, and stop climate change:
#
# 58)Rashida Jones and I talked to Yuval Noah Harari about COVID conspiracy theories, the role social media plays in spreading misinformation, and the one lie I choose to believe even though I know it’s not always true:
#
# 59)I believe we can avoid a climate disaster—if we deploy the clean-energy tools we have now wisely, and if we make big breakthroughs that touch every aspect of our physical economy. Creating the National Institutes of Energy Innovation would put us on the right path.
#
# 60)To reduce duplication, focus the government’s efforts, and get the most innovation out of every dollar of funding, we should create a new organization: the National Institutes of Energy Innovation.
#
# 61)This the most important thing the U.S. can do to lead the world in innovations that will solve climate change.
#
# 62)I’m inspired by Quarraisha Abdool Karim and . They are two of the most respected HIV/AIDS researchers in the world. And now they are helping guide the COVID-19 response in South Africa and around the globe.  WorldAIDSDay
#
# 63): My parents taught me to leave the world better than I found it.
#
# So many people across the country believe in giving bac…
#
# 64)I’m a big fan of author _yuval and was excited to talk to him about why humanity is so willing to believe falsehoods and what these lies tell us about ourselves—both as individuals and as a society.
#
# 65): “I will continue fighting. I will continue supporting other patients. I will never give up.”
#
# Meet Aftab, a multi-drug resi…
#
# 66)Today is the 25th anniversary of my first book, The Road Ahead. I made a lot of predictions about technology in the book, and it was fun to look back and see what I got right (and what I got wrong).
#
# 67)This week, Rashida and I ask a big question that has never felt more urgent: is inequality inevitable? We spoke with Compton mayor  and  director Raj Chetty about what it’ll take to build a more equal society.
#
# 68)You can listen to a bonus clip that didn’t make it into our latest episode here:
#
# 69): Full interview with :
#
# 70)In our first podcast episode, Rashida Jones and I talked to Dr. Anthony Fauci about what to expect in the coming months and what the world will look like after COVID-19.
#
# 71)More than 7 million community health workers serve their neighbors around the world, improving access to primary healthcare for their communities. Now they’re doing heroic work to respond to the pandemic.
#
# 72): No one is safe from COVID-19 until everyone is safe. We started the foundation because we believe every person deserves t…
#
# 73)Each week, we’ll talk about some of the biggest issues facing our world with special guests including authors, experts, and friends.
#
# 74)I’m teaming up with Rashida Jones to ask the big questions. Check out our new podcast limited series starting Monday. You can subscribe here:
#
# 75)I look forward to working with the new administration and leaders on both sides in Congress on getting the surging pandemic under control, engaging partners around the world on issues like poverty and climate change, and addressing issues of inequality and opportunity at home.
#
# 76)Congratulations to President-Elect Biden and Vice President-Elect Harris. Thank you to the election officials and campaign workers who worked tirelessly to ensure a record number of Americans could cast a ballot and have it counted during such an challenging time for our country.
#
# 77)Here in Washington, we always vote by mail. It's a safe and secure way to shape the future of our country. But regardless of whether you vote by mail or in person this year, I hope you plan to make your voice heard. Visit  for more information.

# %%
#Printing all the negative tweets
j = 1
sortedDF = df.sort_values(by = ["Polarity"])
for i in range(0, sortedDF.shape[0]):
    if sortedDF["Analysis"][i] == "Negative":
        print(str(j) + ")" + sortedDF["Tweets"][i])
        print()
        j = j + 1
# Out:
# 1): Black folks have questions about the COVID-19 vaccine. I sat down w/ Black healthcare workers &amp; they answered my questions.…
#
# 2)Recent extreme weather events are a stark reminder that we’re already seeing the effects of climate change here at home and around the world. This type of observation system will help scientists monitor and predict future weather events.
#
# 3)There are several ways individuals can help move us closer to a zero-carbon future. Here are a few:
#
# 4): The Weekly Planet: Lately, Bill Gates has been thinking about what he calls the “hard stuff” of climate change. These hard…
#
# 5): "People who think a plan is easy are wrong. People who think a plan is impossible are wrong. It's super hard and very broad,…
#
# 6): Only 3% of Black students learn computer science in high school or beyond. Please watch and share this video. Inspire a studen…
#
# 7)COVID-19 has cost lives, sickened millions, and thrust the global economy into a devastating recession. But hope is on the horizon:
#
# 8)Here are four other ways that America can advance its leadership on climate change this year and put the world on a path to zero emissions by 2050:
#
# 9)The President’s commitment to reengage with the world gives me hope that the recovery will reach everyone, including communities of color in the U.S. and people in poor countries around the world.
#
# 10)We need to revolutionize the world’s physical economy—and that will take, among other things, a dramatic infusion of ingenuity, funding, and focus from the federal government.
#
# 11)Nearly forty million people have Alzheimer’s or dementia today. We have no way to stop or even slow the disease at this point, but I’m hopeful the new Alzheimer’s Disease Data Initiative () will speed up progress.

# %%
#Plot the polarity and subjectivity
plt.figure(figsize = (8, 6))
for i in range(0, df.shape[0]):
    plt.scatter(df["Polarity"][i], df["Subjectivity"][i], color = "Blue")
    
plt.title("Sentimental Analysis of Tweets")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.show()

# %%
#Get the percentage of positive tweets
ptweets = df[df.Analysis == "Positive"]
ptweets = ptweets["Tweets"]

round(ptweets.shape[0] / df.shape[0] * 100, 1)
# Out:
# 77.0

# %%
#Get the percentage of negative tweets
ntweets = df[df.Analysis == "Negative"]
ntweets = ntweets["Tweets"]

round(ntweets.shape[0] / df.shape[0] * 100, 1)
# Out:
# 11.0

# %%
#Show the value counts
df["Analysis"].value_counts()

plt.title("Sentimental Analysis")
plt.xlabel("Sentiment")
plt.ylabel("Counts")
df["Analysis"].value_counts().plot(kind = "bar")
plt.show()
